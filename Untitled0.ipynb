# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

# Constants
G = 9.81
R_EARTH = 6371000
m_dry = 1000
m_fuel = 4000
Isp = 300
ve = Isp * G
thrust = 50000
burn_time = 60

def rocket_dynamics(t, y, thrust, ve, m_dry, m_fuel, burn_time):
    altitude, velocity, mass = y
    g = G * (R_EARTH / (R_EARTH + altitude))**2

    if t < burn_time and mass > m_dry:
        thrust_force = thrust
        mass_rate = -thrust / ve
    else:
        thrust_force = 0
        mass_rate = 0

    drag = 0.5 * 0.3 * 1.2 * (0.5)**2 * velocity**2
    acceleration = (thrust_force - drag - mass * g) / mass if mass > 0 else -g

    return [velocity, acceleration, mass_rate]

y0 = [0.0, 0.0, m_dry + m_fuel]

sol = solve_ivp(rocket_dynamics, [0, 300], y0,
                args=(thrust, ve, m_dry, m_fuel, burn_time),
                method='RK45', rtol=1e-6, atol=1e-6)

# Plots
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.plot(sol.t, sol.y[0]/1000)
plt.xlabel('Time (s)')
plt.ylabel('Altitude (km)')
plt.title('Altitude vs Time')

plt.subplot(2, 2, 2)
plt.plot(sol.t, sol.y[1])
plt.xlabel('Time (s)')
plt.ylabel('Velocity (m/s)')
plt.title('Velocity vs Time')

plt.subplot(2, 2, 3)
plt.plot(sol.t, sol.y[2])
plt.xlabel('Time (s)')
plt.ylabel('Mass (kg)')
plt.title('Mass vs Time')

plt.tight_layout()
plt.show()

print("Max altitude:", round(max(sol.y[0])/1000, 2), "km")
print("Max velocity:", round(max(sol.y[1]), 1), "m/s")
# Out:
# Max altitude: 2.04 km
# Max velocity: 81.6 m/s

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

# Better parameters (more realistic small rocket)
G = 9.81
R_EARTH = 6371000
m_dry = 25000      # kg (like a small Falcon 9 first stage dry mass)
m_fuel = 350000    # kg
Isp = 311          # seconds (better engine)
ve = Isp * G
thrust = 8_000_000 # 8 MN thrust (~Falcon 9 level for simulation)
burn_time = 180    # 3 minutes burn

def rocket_dynamics(t, y, thrust, ve, m_dry, m_fuel, burn_time):
    altitude, velocity, mass = y
    g = G * (R_EARTH / (R_EARTH + altitude))**2

    if t < burn_time and mass > m_dry:
        thrust_force = thrust
        mass_rate = -thrust / ve
    else:
        thrust_force = 0
        mass_rate = 0

    # Improved drag (less at high altitude)
    rho = 1.225 * np.exp(-altitude / 8500)  # exponential atmosphere
    drag = 0.5 * 0.3 * rho * (5.0)**2 * velocity**2   # Cd=0.3, Area=25m²

    acceleration = (thrust_force - drag - mass * g) / mass if mass > 0 else -g
    return [velocity, acceleration, mass_rate]

y0 = [0.0, 0.0, m_dry + m_fuel]

sol = solve_ivp(rocket_dynamics, [0, 400], y0,
                args=(thrust, ve, m_dry, m_fuel, burn_time),
                method='RK45', rtol=1e-6, atol=1e-6, max_step=1)

# Plot
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.plot(sol.t, sol.y[0]/1000)
plt.xlabel('Time (s)')
plt.ylabel('Altitude (km)')
plt.title('Altitude vs Time')

plt.subplot(2, 2, 2)
plt.plot(sol.t, sol.y[1]/1000)
plt.xlabel('Time (s)')
plt.ylabel('Velocity (km/s)')
plt.title('Velocity vs Time')

plt.subplot(2, 2, 3)
plt.plot(sol.t, sol.y[2]/1000)
plt.xlabel('Time (s)')
plt.ylabel('Mass (tons)')
plt.title('Mass vs Time')

plt.tight_layout()
plt.show()

print("Max altitude reached:", round(max(sol.y[0])/1000, 2), "km")
print("Max velocity reached:", round(max(sol.y[1])/1000, 3), "km/s")
print("Fuel used:", round(m_dry + m_fuel - sol.y[2][-1], 0), "kg")
print("Simulation completed successfully!")
# Out:
# Max altitude reached: 1799.22 km
# Max velocity reached: 6.907 km/s
# Fuel used: 350001.0 kg
# Simulation completed successfully!

# %%
import numpy as np
from scipy.integrate import solve_ivp
from scipy.optimize import minimize_scalar
import matplotlib.pyplot as plt

# Parameters
G = 9.81
R_EARTH = 6371000
m_dry = 25000
m_fuel = 350000
Isp = 311
ve = Isp * G
thrust = 8_000_000

def simulate_rocket(burn_time):
    def rocket_dynamics(t, y):
        altitude, velocity, mass = y
        g = G * (R_EARTH / (R_EARTH + altitude))**2
        rho = 1.225 * np.exp(-altitude / 8500)

        if t < burn_time and mass > m_dry:
            thrust_force = thrust
            mass_rate = -thrust / ve
        else:
            thrust_force = 0
            mass_rate = 0

        drag = 0.5 * 0.3 * rho * 25 * velocity**2
        acceleration = (thrust_force - drag - mass * g) / mass if mass > 0 else -g
        return [velocity, acceleration, mass_rate]

    y0 = [0.0, 0.0, m_dry + m_fuel]
    sol = solve_ivp(rocket_dynamics, [0, 500], y0, method='RK45', rtol=1e-6, atol=1e-6)
    final_velocity = sol.y[1][-1]
    max_alt = max(sol.y[0])
    return -final_velocity, max_alt, sol  # Negative for optimization

# Optimize burn time
result = minimize_scalar(lambda bt: simulate_rocket(bt)[0], bounds=(100, 300), method='bounded')
best_burn_time = result.x
_, best_alt, best_sol = simulate_rocket(best_burn_time)

print("=== OPTIMIZED RESULTS ===")
print("Best burn time:", round(best_burn_time, 1), "seconds")
print("Max altitude:", round(max(best_sol.y[0])/1000, 2), "km")
print("Max velocity:", round(max(best_sol.y[1])/1000, 3), "km/s")

# Plot (optional - you can run this part separately)
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.plot(best_sol.t, best_sol.y[0]/1000)
plt.ylabel('Altitude (km)')
plt.subplot(2, 2, 2)
plt.plot(best_sol.t, best_sol.y[1]/1000)
plt.ylabel('Velocity (km/s)')
plt.tight_layout()
plt.show()
# Out:
# === OPTIMIZED RESULTS ===
# Best burn time: 300.0 seconds
# Max altitude: 2267.1 km
# Max velocity: 6.908 km/s
